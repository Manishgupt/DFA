# %%
data=input("enter string ending with '101' over'01':")
length=len(data)
i=0
if(length>=3):
    
    def check():
        for k in data:
            if(k in "01"):
                pass
            else:
                print("string must be over 1 and 0")
                return
        zero(i)
        
    def zero(i):
        if(length==i):
            print("string is not aceepted")
            return
        elif(data[i]=="1"):
            i+=1
            first(i)
            return
        else:
            i+=1
            zero(i)
            
    def first(i):
        if(length==i):
            print("string is not aceepted")
            return
        elif(data[i]=="0"):
            i+=1
            second(i)
            return
        else:
            i+=1
            zero(i)
    
    def second(i):
        if(length==i):
            print("string is not aceepted")
            return
        elif(data[i]=="1"):
            i+=1
            third(i)
        else:
            i+=1
            zero(i)
            return
        
    def third(i):
        if(length==i):
            print("string is aceepted")
            return
        elif(data[i]=="1"):
            i+=1
            first(i)
        else:
            i+=1
            second(i)
    
    check()
else:
    print("length must be >=3")
