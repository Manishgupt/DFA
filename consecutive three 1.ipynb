# %%
data=str(input("enter string starting with three consecutive 1 over'01':"))
length=len(data)
i=0
if(length>=3):
    def fourth(i):
        if(length==i):
            print("string is aceepted")
            return
        else:
            i+=1
            fourth(i)
        
    def third(i):
        if(length==i):
            print("string is not aceepted")
            return
        elif(data[i]=="1"):
            i+=1
            fourth(i)
        else:
            i+=1
            first(i)
            return
        
    def second(i):
        if(length==i):
            print("string is not aceepted")
            return
        elif(data[i]=="1"):
            i+=1
            third(i)
            return
        else:
            i+=1
            first(i)
            
            
    def first(i):
        if(length==i):
            print("string is not aceepted")
            return
        elif(data[i]=="1"):
            i+=1
            second(i)
            return
        else:
            i+=1
            first(i)
    
    def check():
        for k in data:
            if(k in "01"):
                pass
            else:
                print("string must be over 1 and 0")
                return
        first(i)
    check()
else:
    print("length must be >=3")
