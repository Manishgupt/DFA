# %%
"Written by: Manish gupta-45"
"Written in Python language"

"""The above program is accept string input which is ending with 101 over the input alphabet (0,1) 
which is in binary form.. In the Machine the string is going to accept if "101" occur at the end of string,
    if is not then the string is going to reject it""" 

#just for inform the type of machine 
print("---------------------------------------")
print("|  Welcome to Machine Ending with '101'|")
print("---------------------------------------")
#for iterating the machine when user want to exit press 0

while(True):
    print("Enter 'q' to stop the Machine:")
    
    #taking input string from user
    data=input("enter string :")
    if(data.lower()=='q'):
        print("Exiting....\n","_"*50,"\n                    Terminated")
        break
        
    #length variable is used to store the length of the above input string
    length=len(data)
    
    #i=0 is the temporary variable for calculating the length of the string
    i=0
    if(length>=3):
    
        def check():
            for k in data:
                if(k in "01"):
                    pass
                else:
                    print("--->string must be over 1 and 0\n","_"*50)
                    return
            zero(i)
        
        def zero(i):
            if(length==i):
                print("\n --->string is not accepted \n","_"*50)
                return
            elif(data[i]=="1"):
                i+=1
                first(i)
                return
            else:
                i+=1
                zero(i)
            
        def first(i):
            if(length==i):
                print("\n --->string is not accepted \n","_"*50)
                return
            elif(data[i]=="0"):
                i+=1
                second(i)
                return
            else:
                i+=1
                zero(i)
    
        def second(i):
            if(length==i):
                print("\n --->string is not accepted \n","_"*50)
                return
            elif(data[i]=="1"):
                i+=1
                third(i)
            else:
                i+=1
                zero(i)
                return
        
        def third(i):
            if(length==i):
                print("\n --->string is accepted \n","_"*50)
                return
            elif(data[i]=="1"):
                i+=1
                first(i)
            else:
                i+=1
                second(i)
    
        check()
    #if length is less than our in if condition then it show the length exception
    else:
        print("---->length must be >=3\n","_"*50)
# Out:
# ---------------------------------------
# |  Welcome to Machine Ending with '101'|
# ---------------------------------------
# Enter 'q' to stop the Machine:
# enter string :111
#
#  --->string is not accepted
#  __________________________________________________
# Enter 'q' to stop the Machine:
# enter string :1101
#
#  --->string is not accepted
#  __________________________________________________
# Enter 'q' to stop the Machine:
# enter string :1
# ---->length must be >=3
#  __________________________________________________
# Enter 'q' to stop the Machine:
# enter string :q
# Exiting....
#  __________________________________________________
#                     Terminated
